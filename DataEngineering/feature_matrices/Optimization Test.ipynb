# %%
import cvxpy as cp
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('player_prices_w_pred_Ben.csv')
data.head(50)
# Out:
#     Unnamed: 0 Position                      Name + ID                Name  \
# 0            0        G   Jordan Binnington (13678944)   Jordan Binnington
# 1            1        G    Philipp Grubauer (13678945)    Philipp Grubauer
# 2            2       LW       Alex Ovechkin (13678140)       Alex Ovechkin
# 3            3        G       Braden Holtby (13678946)       Braden Holtby
# 4            4        G         Petr Mrazek (13678947)         Petr Mrazek
# 5            5        C    Nathan MacKinnon (13677890)    Nathan MacKinnon
# 6            6        G  Andrei Vasilevskiy (13678949)  Andrei Vasilevskiy
# 7            7        G        Martin Jones (13678948)        Martin Jones
# 8            8        G         John Gibson (13678950)         John Gibson
# 9            9        G         Carter Hart (13678951)         Carter Hart
# 10          10        G       Thomas Greiss (13678965)       Thomas Greiss
# 11          11        C         Jack Eichel (13677892)         Jack Eichel
# 12          12       RW        Brock Boeser (13678142)        Brock Boeser
# 13          13        G     Jacob Markstrom (13678953)     Jacob Markstrom
# 14          14       LW         Taylor Hall (13678144)         Taylor Hall
# 15          15        D        John Carlson (13678584)        John Carlson
# 16          16        G   Connor Hellebuyck (13678955)   Connor Hellebuyck
# 17          17       LW        Jeff Skinner (13678148)        Jeff Skinner
# 18          18        C    Elias Pettersson (13677894)    Elias Pettersson
# 19          19        G       Linus Ullmark (13678972)       Linus Ullmark
# 20          20       LW         J.T. Miller (13678150)         J.T. Miller
# 21          21        G        Jimmy Howard (13678958)        Jimmy Howard
# 22          22        G      Anton Khudobin (13678973)      Anton Khudobin
# 23          23        C      Steven Stamkos (13677896)      Steven Stamkos
# 24          24       RW     Nikita Kucherov (13678152)     Nikita Kucherov
# 25          25        G    Jonathan Bernier (13678974)    Jonathan Bernier
# 26          26        C           Bo Horvat (13677898)           Bo Horvat
# 27          27        D     Alexander Edler (13678586)     Alexander Edler
# 28          28       LW        Evander Kane (13678156)        Evander Kane
# 29          29        G    Elvis Merzlikins (13678975)    Elvis Merzlikins
# 30          30       LW      Nikolaj Ehlers (13678158)      Nikolaj Ehlers
# 31          31       LW  James van Riemsdyk (13678160)  James van Riemsdyk
# 32          32        C        Tyler Seguin (13677900)        Tyler Seguin
# 33          33        D         Brent Burns (13678588)         Brent Burns
# 34          34       RW      Travis Konecny (13678164)      Travis Konecny
# 35          35        C        Dylan Larkin (13677902)        Dylan Larkin
# 36          36        D    Alex Pietrangelo (13678590)    Alex Pietrangelo
# 37          37        C       Brayden Point (13677904)       Brayden Point
# 38          38        C       Claude Giroux (13677906)       Claude Giroux
# 39          39       RW       Kyle Palmieri (13678168)       Kyle Palmieri
# 40          40       RW      Anthony Mantha (13678170)      Anthony Mantha
# 41          41        D     Dougie Hamilton (13678592)     Dougie Hamilton
# 42          42        C      Mark Scheifele (13677908)      Mark Scheifele
# 43          43        C       Sebastian Aho (13677910)       Sebastian Aho
# 44          44       LW         Kyle Connor (13678172)         Kyle Connor
# 45          45       LW   Alexander Radulov (13678174)   Alexander Radulov
# 46          46        C        Ryan Getzlaf (13677912)        Ryan Getzlaf
# 47          47       LW   Andrei Svechnikov (13678176)   Andrei Svechnikov
# 48          48       RW        David Perron (13678178)        David Perron
# 49          49        D          Seth Jones (13678596)          Seth Jones
#
#           ID Roster Position  Salary                      Game Info  \
# 0   13678944               G    8400  CLS@STL 11/01/2019 08:00PM ET
# 1   13678945               G    8200  DAL@COL 11/01/2019 09:00PM ET
# 2   13678140          W/UTIL    8100  BUF@WAS 11/01/2019 07:00PM ET
# 3   13678946               G    8100  BUF@WAS 11/01/2019 07:00PM ET
# 4   13678947               G    8000  DET@CAR 11/01/2019 07:30PM ET
# 5   13677890          C/UTIL    8000  DAL@COL 11/01/2019 09:00PM ET
# 6   13678949               G    7900   TB@NYI 11/01/2019 07:00PM ET
# 7   13678948               G    7800   WPG@SJ 11/01/2019 10:30PM ET
# 8   13678950               G    7700  VAN@ANH 11/01/2019 10:00PM ET
# 9   13678951               G    7600   PHI@NJ 11/01/2019 07:00PM ET
# 10  13678965               G    7600   TB@NYI 11/01/2019 07:00PM ET
# 11  13677892          C/UTIL    7500  BUF@WAS 11/01/2019 07:00PM ET
# 12  13678142          W/UTIL    7500  VAN@ANH 11/01/2019 10:00PM ET
# 13  13678953               G    7500  VAN@ANH 11/01/2019 10:00PM ET
# 14  13678144          W/UTIL    7400   PHI@NJ 11/01/2019 07:00PM ET
# 15  13678584          D/UTIL    7300  BUF@WAS 11/01/2019 07:00PM ET
# 16  13678955               G    7300   WPG@SJ 11/01/2019 10:30PM ET
# 17  13678148          W/UTIL    7200  BUF@WAS 11/01/2019 07:00PM ET
# 18  13677894          C/UTIL    7200  VAN@ANH 11/01/2019 10:00PM ET
# 19  13678972               G    7100  BUF@WAS 11/01/2019 07:00PM ET
# 20  13678150          W/UTIL    7100  VAN@ANH 11/01/2019 10:00PM ET
# 21  13678958               G    7000  DET@CAR 11/01/2019 07:30PM ET
# 22  13678973               G    7000  DAL@COL 11/01/2019 09:00PM ET
# 23  13677896          C/UTIL    7000   TB@NYI 11/01/2019 07:00PM ET
# 24  13678152          W/UTIL    7000   TB@NYI 11/01/2019 07:00PM ET
# 25  13678974               G    6800  DET@CAR 11/01/2019 07:30PM ET
# 26  13677898          C/UTIL    6800  VAN@ANH 11/01/2019 10:00PM ET
# 27  13678586          D/UTIL    6800  VAN@ANH 11/01/2019 10:00PM ET
# 28  13678156          W/UTIL    6800   WPG@SJ 11/01/2019 10:30PM ET
# 29  13678975               G    6700  CLS@STL 11/01/2019 08:00PM ET
# 30  13678158          W/UTIL    6700   WPG@SJ 11/01/2019 10:30PM ET
# 31  13678160          W/UTIL    6600   PHI@NJ 11/01/2019 07:00PM ET
# 32  13677900          C/UTIL    6600  DAL@COL 11/01/2019 09:00PM ET
# 33  13678588          D/UTIL    6600   WPG@SJ 11/01/2019 10:30PM ET
# 34  13678164          W/UTIL    6500   PHI@NJ 11/01/2019 07:00PM ET
# 35  13677902          C/UTIL    6500  DET@CAR 11/01/2019 07:30PM ET
# 36  13678590          D/UTIL    6400  CLS@STL 11/01/2019 08:00PM ET
# 37  13677904          C/UTIL    6400   TB@NYI 11/01/2019 07:00PM ET
# 38  13677906          C/UTIL    6300   PHI@NJ 11/01/2019 07:00PM ET
# 39  13678168          W/UTIL    6300   PHI@NJ 11/01/2019 07:00PM ET
# 40  13678170          W/UTIL    6200  DET@CAR 11/01/2019 07:30PM ET
# 41  13678592          D/UTIL    6200  DET@CAR 11/01/2019 07:30PM ET
# 42  13677908          C/UTIL    6200   WPG@SJ 11/01/2019 10:30PM ET
# 43  13677910          C/UTIL    6100  DET@CAR 11/01/2019 07:30PM ET
# 44  13678172          W/UTIL    6100   WPG@SJ 11/01/2019 10:30PM ET
# 45  13678174          W/UTIL    6000  DAL@COL 11/01/2019 09:00PM ET
# 46  13677912          C/UTIL    6000  VAN@ANH 11/01/2019 10:00PM ET
# 47  13678176          W/UTIL    5900  DET@CAR 11/01/2019 07:30PM ET
# 48  13678178          W/UTIL    5900  CLS@STL 11/01/2019 08:00PM ET
# 49  13678596          D/UTIL    5900  CLS@STL 11/01/2019 08:00PM ET
#
#    TeamAbbrev  AvgPointsPerGame  lgbm_projection  Linear_DFS_Prediction  \
# 0         STL             15.68            14.82              13.629441
# 1         COL             16.70            13.33               0.000000
# 2         WAS             19.41            12.89              15.984278
# 3         WAS             10.99            13.90              13.269326
# 4         CAR             14.68            12.60               0.000000
# 5         COL             16.45            15.82              14.774305
# 6          TB             15.72            13.78              14.412698
# 7          SJ              9.00            14.06               0.000000
# 8         ANH             15.19            13.88               0.000000
# 9         PHI              4.97             9.11               0.000000
# 10        NYI             16.90            16.68              11.984458
# 11        BUF             16.22            13.47              13.898224
# 12        VAN             14.12            11.96              11.184300
# 13        VAN             15.42            13.46              13.498725
# 14         NJ             11.69            13.24              12.747874
# 15        WAS             18.34            11.56              13.235058
# 16        WPG             15.92            13.64               0.000000
# 17        BUF             13.52            11.12              11.679537
# 18        VAN             13.83            12.18              10.093601
# 19        BUF             22.28            11.73               0.000000
# 20        VAN             12.98            10.39              10.678253
# 21        DET             14.20            14.51              14.781458
# 22        DAL             10.26            15.24               0.000000
# 23         TB             12.36            10.98              11.031038
# 24         TB             10.93             9.44              10.432475
# 25        DET              9.48            13.04              11.521749
# 26        VAN             13.43            10.02              10.932135
# 27        VAN             14.34            10.97              11.254601
# 28         SJ             15.92            12.26              11.707324
# 29        CLS              8.13            14.02               0.000000
# 30        WPG             13.30            10.03              10.110420
# 31        PHI             11.40            10.34              10.677968
# 32        DAL             10.12            11.23              10.302850
# 33         SJ             12.48            11.31              11.670806
# 34        PHI             11.84             8.01               9.040551
# 35        DET             11.96            12.03              12.639814
# 36        STL             11.82            11.03              11.055488
# 37         TB             12.38             8.99               8.540148
# 38        PHI             10.29             9.59              10.065725
# 39         NJ             12.12            10.18              10.172290
# 40        DET             14.62            13.27              13.104422
# 41        CAR             15.24            11.68              11.394663
# 42        WPG             10.27            10.10              11.076100
# 43        CAR              9.08            11.58              10.739455
# 44        WPG             11.00            13.07              11.425895
# 45        DAL              9.85            11.48               9.531657
# 46        ANH             10.71             9.74              10.654869
# 47        CAR             11.19            10.16               9.868099
# 48        STL             10.87             9.22               9.392382
# 49        CLS             10.58             9.42               9.962092
#
#     NN_DFS_Prediction
# 0           12.577880
# 1            0.000000
# 2           15.968162
# 3           11.892563
# 4            0.000000
# 5           14.399432
# 6           12.497589
# 7            0.000000
# 8            0.000000
# 9            0.000000
# 10          12.216659
# 11          13.728931
# 12          12.074656
# 13          12.610475
# 14          12.527755
# 15          12.320908
# 16           0.000000
# 17          11.900285
# 18          11.471531
# 19           0.000000
# 20          11.752981
# 21          13.278547
# 22           0.000000
# 23          11.022712
# 24          10.874104
# 25          11.694061
# 26          12.363957
# 27          10.466511
# 28          11.539296
# 29           0.000000
# 30           9.796558
# 31          10.716110
# 32          10.195844
# 33          10.623837
# 34           8.848474
# 35          12.721105
# 36           9.725712
# 37           9.047829
# 38          10.885507
# 39          10.736578
# 40          12.279971
# 41          10.208532
# 42          11.648293
# 43          10.328430
# 44          12.251986
# 45          10.140450
# 46          10.770122
# 47          10.081073
# 48           9.771486
# 49           9.500438

# %%
#Test of forcing player selection
already_selected=[]
#already_selected = ['Ilya Samsonov','Elias Pettersson', 'Alex Ovechkin']

already_selected_data = data.loc[data['Name'].isin(already_selected)]

C_selected = already_selected_data.loc[already_selected_data['Position']=='C'].count()['Position']
D_selected = already_selected_data.loc[already_selected_data['Position']=='D'].count()['Position']
W_selected = already_selected_data.loc[already_selected_data['Position'].isin(['LW','RW'])].count()['Position']
G_selected = already_selected_data.loc[already_selected_data['Position']=='G'].count()['Position']
total_selected = C_selected + W_selected + D_selected + G_selected
selected_salary = np.sum(already_selected_data['Salary'])

data = data.loc[~data['Name'].isin(already_selected)]

# %% [markdown]
# Create Variable arrays for model

# %%
salary = np.array(data['Salary'])
projected_DFS = np.array(data['NN_DFS_Prediction'])
center = np.array(data['Position']=='C')
winger = np.array(np.logical_or(data['Position']=='LW',data['Position']=='RW'))
defense = np.array(data['Position']=='D')
goalie = np.array(data['Position']=='G')
selection = cp.Variable(len(salary), boolean=True)
budget = 50000-selected_salary
max_players = 8-total_selected

# %% [markdown]
# Create Constraints

# %%
budget_constraint = salary*selection <= budget
player_constraint = sum(selection) == max_players
center_min = selection*center >=2-C_selected
center_max = selection*center <=3-C_selected
winger_min = selection*winger >=2-W_selected
winger_max = selection*winger <=3-W_selected
defender_min = selection*defense >=2-D_selected
defender_max = selection*defense <=3-D_selected
goalie_constraint = selection*goalie == 1-G_selected

# %% [markdown]
# Objective Function

# %%
total_projected_value = projected_DFS * selection
objective = cp.Problem(cp.Maximize(total_projected_value), [budget_constraint,player_constraint, center_min, center_max, winger_min, winger_max, defender_min, defender_max, goalie_constraint])

# %%
objective.solve()
# Out:
# 98.68757000144832

# %% [markdown]
# Create Optimal Player List

# %%
opt_selection = selection.value >= 0.9
player_list = data['Name'][opt_selection].append(already_selected_data['Name'])
opt_positions = data['Position'][opt_selection].append(already_selected_data['Position'])
opt_salary = data['Salary'][opt_selection].append(already_selected_data['Salary'])
print(player_list.tolist())
print(opt_positions)
print(np.sum(opt_salary))
print(type(player_list.tolist()))
# Out:
# ['Alex Ovechkin', 'Nathan MacKinnon', 'John Carlson', 'Jimmy Howard', 'Dylan Larkin', 'Blake Wheeler', 'Gustav Nyquist', 'Samuel Girard']
# 2      LW
# 5       C
# 15      D
# 21      G
# 35      C
# 52     RW
# 148    LW
# 156     D
# Name: Position, dtype: object
# 49800
# <class 'list'>
